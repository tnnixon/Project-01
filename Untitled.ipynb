# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
student_mat = pd.read_csv("student-mat.csv")
student_por = pd.read_csv("student-por.csv")

merged_data = pd.merge(student_mat, student_por, on="school")
#merged_data.head()
student_mat.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
student_por.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
merged_data.head()
# Out:
#   school sex_x  age_x address_x famsize_x Pstatus_x  Medu_x  Fedu_x   Mjob_x  \
# 0     GP     F     18         U       GT3         A       4       4  at_home
# 1     GP     F     18         U       GT3         A       4       4  at_home
# 2     GP     F     18         U       GT3         A       4       4  at_home
# 3     GP     F     18         U       GT3         A       4       4  at_home
# 4     GP     F     18         U       GT3         A       4       4  at_home
#
#     Fjob_x  ... famrel_y freetime_y  goout_y  Dalc_y  Walc_y health_y  \
# 0  teacher  ...        4          3        4       1       1        3
# 1  teacher  ...        5          3        3       1       1        3
# 2  teacher  ...        4          3        2       2       3        3
# 3  teacher  ...        3          2        2       1       1        5
# 4  teacher  ...        4          3        2       1       2        5
#
#   absences_y G1_y G2_y G3_y
# 0          4    0   11   11
# ...

# %%
#variables
school = merged_data["school"]
age = merged_data["age_x"] 
freetime = merged_data["freetime_y"]
absences = merged_data["absences_y"]
gender = merged_data["sex_x"]
#freetime_avg = freetime.mean()
#freetime_avg
print(absences)
# Out:
# 0         4
# 1         2
# 2         6
# 3         0
# 4         0
#          ..
# 158018    4
# 158019    4
# 158020    6
# 158021    6
# 158022    4
# Name: absences_y, Length: 158023, dtype: int64

# %%
try:
    plt.scatter(age, gender, marker="o", color="red")
    plt.show()
except:
    print("this not correct")
# Out:
# <img src="data:image/png;base64,..." width="640">
